# %%
from matplotlib import pyplot as plt

# %%
mse = [114.14, 238.25, 296.36, 1308.86, 3371.55]
matrix_size = [1019, 764, 509, 203, 101]
fig = plt.figure()
plt.plot(matrix_size, mse)
# fig.suptitle('', fontsize=20)
plt.xlabel('liczba punktów', fontsize=12)
plt.ylabel('błąd średnio kwadratowy', fontsize=12)
plt.show()
fig.savefig('./mse_matrix_size.jpg')

# %% [markdown]
# # Nowa sekcja

# %%
time_master = list(reversed([19.84/270.1*100, 11.2/205.82*100, 4.95/137.25*100, 0.95/64.78*100, 0.29/45.39*100]))
matrix = list(reversed(['1020x1020', '765x765', '510x510', '204x204', '102x102']))
fig = plt.figure()
plt.plot(matrix, time_master)
# fig.suptitle('matrix_size - percent', fontsize=12)
plt.xlabel('wymiar macierzy', fontsize=12)
plt.ylabel('czas pracy na węźle głównym [%]', fontsize=12)
fig.savefig('./percent_time_in_master_3.jpg')
plt.show()

# %%
# procentowy udział czasu węzła głównego w zależności od wielkości macierzy
time_master = list(reversed([19.84, 11.2, 4.95, 0.95, 0.29]))
matrix = list(reversed(['1020x1020', '765x765', '510x510', '204x204', '102x102']))
fig = plt.figure()
plt.plot(matrix, time_master)
# fig.suptitle('matrix_size - percent', fontsize=12)
plt.xlabel('wymiar macierzy', fontsize=12)
plt.ylabel('czas pracy na węźle głównym [S]', fontsize=12)
plt.show()
fig.savefig('./time_in_master.jpg')

# %%
time = [65.43, 85.35, 79.35, 155.83, 273.12]
partitions = [16, 8, 4, 2, 1]
fig = plt.figure()
plt.plot(partitions, time)
# fig.suptitle('ilość partycji - czas wykonania', fontsize=20)
plt.xlabel('liczba partycji', fontsize=12)
plt.ylabel('całkowity czas [S]', fontsize=12)
plt.show()
fig.savefig('./partitions_time.jpg')

# %%
time = [48.28, 82.86]
threds = ['konfiguracja a', 'konfiguracja b']
fig = plt.figure()
plt.bar(threds, time)
# fig.suptitle('ilość partycji - czas wykonania', fontsize=20)
plt.xlabel('konfiguracja klastra', fontsize=12)
plt.ylabel('czas wykonania [S]', fontsize=12)
plt.show()
fig.savefig('./typy_procesora.jpg')

# %%
time = [47.2, 65.43]
threds = ['konfiguracja a', 'konfiguracja b']
fig = plt.figure()
plt.bar(threds, time)
# fig.suptitle('ilość partycji - czas wykonania', fontsize=20)
plt.xlabel('konfiguracja klastra', fontsize=12)
plt.ylabel('czas wykonania [S]', fontsize=12)
plt.show()
fig.savefig('./konfiguracje_1.jpg')

# %%
time = [286.4, 402.18, 596.04]
conf = ['konfiguracja a', 'konfiguracja b', 'konfiguracja c']
fig = plt.figure()
plt.bar(conf, time)
# fig.suptitle('ilość partycji - czas wykonania', fontsize=20)
plt.xlabel('konfiguracja klastra', fontsize=12)
plt.ylabel('czas wykonania [S]', fontsize=12)
plt.show()
fig.savefig('./konfiguracje_a_b_c.jpg')

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
data = [[ 250.21, 194.62,  132.2, 63.82,  45.1],
        [ 19.84, 11.2,  4.95,  0.95, 0.29]]

columns = ('1020x1020', '765x765', '510x510', '204x204', '102x102')
rows = ['węzęł główny', 'węzły robocze']

values = np.arange(0, 350, 50)
value_increment = 50

# Get some pastel shades for the colors
colors = plt.cm.RdPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns))
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append([x for x in data[row]])

# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("Czas obliczeń [S]")
plt.yticks(values, ['%d' % val for val in values])
plt.xticks([])
plt.title('Wpływ wymiaru macierzy na rozkład obliczeń między węzłami')

plt.show()
fig.savefig('./wielkość_macierzy_a_obliczenia.jpg')
